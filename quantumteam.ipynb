# %% [markdown]
# <a href="https://colab.research.google.com/github/rbhaskarreddy/QRNG-QISKIT-HACKTON2025/blob/main/quantumteam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit

# %%
# !pip install qiskit[visualization]

# %%
from qiskit import QuantumCircuit, transpile

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
from qiskit_aer import AerSimulator

# %%
# Create a Quantum Circuit with one qubit and one classical bit
qc = QuantumCircuit(1, 1)

# %%
# Apply a Hadamard gate to put the qubit in superposition
qc.h(0)

# Measure the qubit and store the result in the classical bit
qc.measure(0, 0)

# %%
# !pip install qiskit-aer

# %%
# Select the AerSimulator as the backend
simulator = AerSimulator()
from qiskit_aer import AerSimulator

# %%
# Transpile the circuit for the simulator
compiled_circuit = transpile(qc, simulator)

# %%
# Run the circuit on the simulator
job = simulator.run(compiled_circuit, shots=1024)

# %%
# Get the results
result = job.result()

# %%
# Get the measurement counts
counts = result.get_counts(qc)

# %%
# Print the results
print("QUANTUM TEAM2025 - PDF ON Quantum BY CHRISTINE MUSCHIK:")
print("QUANTUM TEAM2025 - PDF ON Quantum IN QUANTUM SIMULATION;QUANTUM HARDWARE; QUANTUM ERROR CORRECTION;QUANTUM SENSING;QML:")

print(f"Measurement results: {counts}")
# Out:
# QUANTUM TEAM2025 - PDF ON Quantum BY CHRISTINE MUSCHIK:
# QUANTUM TEAM2025 - PDF ON Quantum IN QUANTUM SIMULATION;QUANTUM HARDWARE; QUANTUM ERROR CORRECTION;QUANTUM SENSING;QML:
# Measurement results: {'1': 505, '0': 519}
